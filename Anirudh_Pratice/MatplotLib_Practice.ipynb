# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import randint

# %%
'''Give 20 linearly spaced number from 0 to 10.'''
x=np.linspace(0,10,20)

# %%
x
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
'''Give 20 random numbers from 0 to 50'''
y=randint(0,50,20)

# %%
y
# Out:
# array([29, 33, 42, 48, 42, 42, 21, 15,  6, 42, 40, 17, 45, 33, 15, 31, 43,
#        11, 35, 18])

# %%
y=np.sort(y)

# %%
# %matplotlib inline

# %%
import numpy as np  

a = np.array([[10,2,3],[4,6,5],[8,7,9]])  

print(a)

print("Sorting along the rows:")  
print(np.sort(a))  

print("Sorting along the column:")  
print(np.sort(a, axis=0))  

data_type = np.dtype([('name', 'S10'),('marks',int)])  

arr = np.array([('Mukesh',200),('John',251)],dtype = data_type)  

print("Sorting data ordered by name")  

print(np.sort(arr,order = 'name'))  

print(np.sort(arr,kind='merge',order='name')) # By defualt kind is quick sort
# Out:
# [[10  2  3]
#  [ 4  6  5]
#  [ 8  7  9]]
# Sorting along the rows:
# [[ 2  3 10]
#  [ 4  5  6]
#  [ 7  8  9]]
# Sorting along the column:
# [[ 4  2  3]
#  [ 8  6  5]
#  [10  7  9]]
# Sorting data ordered by name
# [(b'John', 251) (b'Mukesh', 200)]
# [(b'John', 251) (b'Mukesh', 200)]

# %%
plt.plot(x,y)

# %%
# We can also add xlabel, ylabel or title to above
plt.plot(x,y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Random')
# Out:
# Text(0.5, 1.0, 'Random')

# %%
# To hide that text label
'''Shows the graph and not printing'''
plt.plot(x,y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Random')
plt.show()

# %%
# Time to color something
plt.plot(x,y,color='c') # c for cyan
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Random')
plt.show()

# %%
# Time to color something
plt.plot(x,y,color='red') 
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Random')
plt.show()

# %%
# Add linestyle
plt.plot(x,y,color='black',linestyle='--') 
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Random')
plt.show()

# %%
# Add Marker
plt.plot(x,y,color='black',linestyle='--',marker='*') 
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Random')
plt.show()

# %%
# Increase Marker size
plt.plot(x,y,color='black',linestyle='--',marker='*',markersize=10) 
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Random')
plt.show()

# %%
# Increase line width
plt.plot(x,y,color='purple',linestyle='--',marker='*',markersize=10,linewidth=5.5) 
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Random')
plt.show()

# %%
# Use short notation 
plt.plot(x,y,color='black',ls='--',marker='*',ms=10,lw=5.5) 
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Random')
plt.show()

# %%
# Understanding Multiple plots on same canvas.
'''We use subplot for multiple plots'''
plt.subplot(1,2,1) # no.of rows,then column, then plot we are referring to.
plt.plot(x,y,c='red')
plt.subplot(1,2,2) # no.of rows,then column, then plot we are referring to.
plt.plot(x,y,c='purple')
'''We can see there is one row and 2 columns'''
# Out:
# 'We can see there is one row and 2 columns'

# %%
# Understanding Multiple plots on same canvas.
'''We use subplot for multiple plots'''
plt.subplot(1,3,1) # no.of rows,then column, then plot we are referring to.
plt.plot(x,y,c='red')
plt.subplot(1,3,2) # no.of rows,then column, then plot we are referring to.
plt.plot(x,y,c='purple')
'''We can see there is one row and 2 columns'''
plt.subplot(1,3,3) # Give 1st and 3rd .
plt.plot(x,y,c='green')

# %%
# Understanding Multiple plots on same canvas.
'''We use subplot for multiple plots'''
plt.subplot(1,2,1) # no.of rows,then column, then plot we are referring to.
plt.plot(x,y,c='red')
plt.subplot(1,2,2) # no.of rows,then column, then plot we are referring to.
plt.plot(x,y,c='purple')
'''We can see there is one row and 2 columns'''
plt.subplot(2,3,3) 
plt.plot(x,y,c='green')

# %%
# %matplotlib inline

# %%
# Using Object oriented methods of Pylot
fig=plt.figure()
'''This is imaginary blank canvas'''
# Out:
# 'This is imaginary blank canvas'

# %%
# Add Canvas to this fig ()
fig=plt.figure()
axes=fig.add_axes([0.5,1,1,1])
# Left ,bottom,width,height
axes.plot(x,y)

# %%
fig=plt.figure()
axes=fig.add_axes([0.5,1,1,1])
axes.set_xlabel('X')
axes.set_ylabel('Y')
axes.set_title('Random')
axes.plot(x,y)

# %%
fig,axes=plt.subplots(nrows=2,ncols=3)

# %%
# there is overlapping above
fig,axes=plt.subplots(nrows=2,ncols=3)
plt.tight_layout()

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7faa637b0f10>,
# ...
#       dtype=object)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
for current_ax in axes:
    current_ax.plot(x,y)

# %%
'''If you select nrows=2 ,then we need to use two loops'''
fig,axes=plt.subplots(nrows=2,ncols=2)
for current_axis in axes:
    for ax in current_axis:
        ax.plot(x,y)

# %%
'''You can also do like this.'''
cols=2
fig,axes=plt.subplots(nrows=1,ncols=cols)
for i in range(0,cols):
    axes[i].plot(x,y)

# %%
'''If you have 3 rows then you don't need to use 3 loops'''
cols=3
rows=3
fig,axes=plt.subplots(nrows=rows,ncols=cols)
plt.tight_layout()
for current_axis in axes:
    for j in range (cols):
        current_axis[j].plot(x,y)

# %%
'''If you have 3 rows then you don't need to use 3 loops'''
cols=2
rows=2
fig,axes=plt.subplots(nrows=rows,ncols=cols)
plt.tight_layout()
for i,current_axis in enumerate(axes):
    for j in range (cols):
        current_axis[j].set_title('Plot {} and Subplot {}'.format(i+1,j+1))
        current_axis[j].plot(x,y)

# %%
# figsize=(width,height)
fig=plt.figure(figsize=(5,3),dpi=100) # dot per inch dpi
axes=fig.add_axes([0.5,1,1,1])
axes.set_xlabel('X')
axes.set_ylabel('Y')
axes.set_title('Random')
axes.plot(x,y)

# %%
'''If you have 3 rows then you don't need to use 3 loops'''
cols=2
rows=2
fig,axes=plt.subplots(nrows=rows,ncols=cols,figsize=(12,12))
plt.tight_layout()
for i,current_axis in enumerate(axes):
    for j in range (cols):
        current_axis[j].set_title('Plot {} and Subplot {}'.format(i+1,j+1))
        current_axis[j].plot(x,y)

# %%
fig.savefig('aachaji.png')

# %%
# Specify legends
# figsize=(width,height)
fig=plt.figure(figsize=(5,3),dpi=100) # dot per inch dpi
axes=fig.add_axes([0.5,1,1,1])
axes.plot(x,x**2,label='X vs X^2')
axes.plot(x,x**3,label='X vs X^3')

# %%
# Specify legends
# figsize=(width,height)
fig=plt.figure(figsize=(5,3),dpi=100) # dot per inch dpi
axes=fig.add_axes([0.5,1,1,1])
axes.plot(x,x**2,label='X vs X^2',c='blue')
axes.plot(x,x**3,label='X vs X^3',c='orange')
axes.legend()

# %%
# Change the location of legend
fig=plt.figure(figsize=(5,3),dpi=100) # dot per inch dpi
axes=fig.add_axes([0.5,1,1,1])
axes.plot(x,x**2,label='X vs X^2',c='blue')
axes.plot(x,x**3,label='X vs X^3',c='orange')
axes.legend(loc=6) # Best is 0

# %%
# Understanding Scatter Plot
'''
Here all the data points are represented by a dot.
'''
y_views=[1,2.4,3,4]
f_views=[25,35,47,78]
t_views=[100,200,300,400]
days=[1,2,3,4]
plt.scatter(days,y_views,label='Youtube Views',marker='o')

# %%
plt.scatter(days,y_views,label='Youtube Views',marker='o')
plt.scatter(days,f_views,label='Facebook Views',marker='o')

# %%
plt.scatter(days,y_views,label='Youtube Views',marker='o')
plt.scatter(days,f_views,label='Facebook Views',marker='o')
plt.scatter(days,t_views,label='Twitter Views',marker='o')

# %%
plt.scatter(days,y_views,label='Youtube Views',marker='o')
plt.scatter(days,f_views,label='Facebook Views',marker='o')
plt.scatter(days,t_views,label='Twitter Views',marker='o')
plt.xlabel('Days')
plt.ylabel('Views')
plt.title('Social Media Views')
# Out:
# Text(0.5, 1.0, 'Social Media Views')

# %%
# Which color means what ?? --> Add legend
plt.scatter(days,y_views,label='Youtube Views',marker='o')
plt.scatter(days,f_views,label='Facebook Views',marker='o')
plt.scatter(days,t_views,label='Twitter Views',marker='o')
plt.xlabel('Days')
plt.ylabel('Views')
plt.title('Social Media Views')
plt.legend()

# %%
# Add Grid
plt.scatter(days,y_views,label='Youtube Views',marker='o')
plt.scatter(days,f_views,label='Facebook Views',marker='o')
plt.scatter(days,t_views,label='Twitter Views',marker='o')
plt.xlabel('Days')
plt.ylabel('Views')
plt.title('Social Media Views')
plt.grid(color='black',linestyle='--')
plt.legend()

# %%
# Bar Plot
'''
We use bar plots to remember numerical values in a dataset
to show how different data points vary from each other
'''
# plt.bar(days,y_views,label='Youtube Views')
# plt.bar(days,f_views,label='Facebook Views')
plt.bar(days,t_views,label='Twitter Views')
plt.xlabel('Days')
plt.ylabel('Views')
plt.title('Social Media Views')
plt.grid(color='black',linestyle='--')
plt.legend()

# %%
# Bar Plot
'''
We use bar plots to remember numerical values in a dataset
to show how different data points vary from each other
'''
# plt.bar(days,y_views,label='Youtube Views')
plt.bar(days,f_views,label='Facebook Views')
#plt.bar(days,t_views,label='Twitter Views')
plt.xlabel('Days')
plt.ylabel('Views')
plt.title('Social Media Views')
plt.grid(color='black',linestyle='--')
plt.legend()

# %%
# Bar Plot
'''
We use bar plots to remember numerical values in a dataset
to show how different data points vary from each other
'''
plt.bar(days,y_views,label='Youtube Views')
# plt.bar(days,f_views,label='Facebook Views')
# plt.bar(days,t_views,label='Twitter Views')
plt.xlabel('Days')
plt.ylabel('Views')
plt.title('Social Media Views')
#plt.grid(color='black',linestyle='--')
plt.legend()

# %%
y_views1=[1,2.4,3,4]
f_views1=[40,35,80,240]
t_views1=[50,10,70,80]
days1=[1,2,3,4]

# %%
# Bar Plot
'''
We use bar plots to remember numerical values in a dataset
to show how different data points vary from each other.
With Bar Plot , we can compare values
'''
# plt.bar(days,y_views,label='Youtube Views')
plt.bar(days1,f_views1,label='Facebook Views')
plt.bar(days1,t_views1,label='Twitter Views')
plt.xlabel('Days')
plt.ylabel('Views')
plt.title('Social Media Views')
#plt.grid(color='black',linestyle='--')
plt.legend()

# %%
# Histogram
'''It is a graphical representation of the distribution of a numerical data'''
import random
points=[random.randint(1,120) for x in range(16)]
bins=[20*i for i in range(7)]
print(points)
print(bins)
# Out:
# [92, 20, 91, 62, 118, 19, 74, 86, 110, 74, 73, 12, 75, 49, 20, 26]
# [0, 20, 40, 60, 80, 100, 120]

# %%
plt.hist(points,bins)
# Out:
# (array([2., 3., 1., 5., 3., 2.]),
#  array([  0,  20,  40,  60,  80, 100, 120]),
#  <a list of 6 Patch objects>)

# %%
plt.hist(points,bins)
plt.xlabel('Bins')
plt.ylabel('Points')
plt.title('Random')
# Out:
# Text(0.5, 1.0, 'Random')

# %%
# Pie chart
labels_1=['Facebook','Instagram','Youtube','LinkedIn']
views=[300,350,40,450]

# %%
plt.pie(views,labels=labels_1)
# Out:
# ([<matplotlib.patches.Wedge at 0x7faa61c5ced0>,
# ...
#  [Text(0.7450097048603818, 0.8092963237676587, 'Facebook'),
#   Text(-0.9526279613277876, 0.5499999702695114, 'Instagram'),
#   Text(-0.9371113473566874, -0.5760402092348539, 'Youtube'),
#   Text(0.3571694673931418, -1.0403989482703735, 'LinkedIn')])

# %%
plt.pie(views,labels=labels_1,autopct='%1.1f%%')
plt.show()

# %%
explode_1=[0,0,0,0.2]
plt.pie(views,labels=labels_1,autopct='%1.1f%%',explode=explode_1)
plt.show()

# %%
explode_1=[0,0,0,0.2]
plt.pie(views,labels=labels_1,autopct='%1.1f%%',explode=explode_1,shadow=True)
plt.show()
